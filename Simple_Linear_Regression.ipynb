# %% [markdown]
# **Salary Data**

# %%
import numpy as np
import pandas as pd

# %%
from google.colab import files
uploaded= files.upload()
# Out:
#      <input type="file" id="files-8c126efa-5da4-481d-81fc-1939763706c6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8c126efa-5da4-481d-81fc-1939763706c6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
Salary=pd.read_csv("Salary_Data.csv")
Salary
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
Salary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     float64
# dtypes: float64(2)
# memory usage: 608.0 bytes

# %%
Salary.isnull().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(5,5))
sns.scatterplot(x='YearsExperience',y='Salary',data=Salary,palette='Set1')
# Out:
# <ipython-input-6-355503f6d2b4>:4: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(x='YearsExperience',y='Salary',data=Salary,palette='Set1')
# <Axes: xlabel='YearsExperience', ylabel='Salary'>

# %%
Salary.corr()
# Out:
#                  YearsExperience    Salary
# YearsExperience         1.000000  0.978242
# Salary                  0.978242  1.000000

# %%
import seaborn as sns
sns.distplot(Salary['YearsExperience'])
# Out:
# <ipython-input-8-fcb6dafe5f1c>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(Salary['YearsExperience'])
# <Axes: xlabel='YearsExperience', ylabel='Density'>

# %%
import seaborn as sns
sns.distplot(Salary['Salary'])
# Out:
# <ipython-input-9-c2d93f63ea72>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(Salary['Salary'])
# <Axes: xlabel='Salary', ylabel='Density'>

# %%
import statsmodels.formula.api as smf

# %%
model = smf.ols("Salary~YearsExperience",data=Salary).fit()
Salary
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
import seaborn as sns
sns.regplot(x='YearsExperience',y='Salary',data=Salary)
# Out:
# <Axes: xlabel='YearsExperience', ylabel='Salary'>

# %%
model.params
# Out:
# Intercept          25792.200199
# YearsExperience     9449.962321
# dtype: float64

# %%
Salary.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
model.fittedvalues
# Out:
# 0      36187.158752
# 1      38077.151217
# 2      39967.143681
# 3      44692.124842
# 4      46582.117306
# 5      53197.090931
# 6      54142.087163
# 7      56032.079627
# 8      56032.079627
# 9      60757.060788
# 10     62647.053252
# 11     63592.049484
# 12     63592.049484
# 13     64537.045717
# 14     68317.030645
# 15     72097.015574
# 16     73987.008038
# 17     75877.000502
# 18     81546.977895
# 19     82491.974127
# 20     90051.943985
# 21     92886.932681
# 22    100446.902538
# 23    103281.891235
# 24    108006.872395
# 25    110841.861092
# 26    115566.842252
# 27    116511.838485
# 28    123126.812110
# 29    125016.804574
# dtype: float64

# %%
Salary['Predicted']=model.fittedvalues
Salary
# Out:
#     YearsExperience    Salary      Predicted
# 0               1.1   39343.0   36187.158752
# 1               1.3   46205.0   38077.151217
# 2               1.5   37731.0   39967.143681
# 3               2.0   43525.0   44692.124842
# 4               2.2   39891.0   46582.117306
# 5               2.9   56642.0   53197.090931
# 6               3.0   60150.0   54142.087163
# 7               3.2   54445.0   56032.079627
# 8               3.2   64445.0   56032.079627
# 9               3.7   57189.0   60757.060788
# 10              3.9   63218.0   62647.053252
# 11              4.0   55794.0   63592.049484
# 12              4.0   56957.0   63592.049484
# 13              4.1   57081.0   64537.045717
# 14              4.5   61111.0   68317.030645
# 15              4.9   67938.0   72097.015574
# 16              5.1   66029.0   73987.008038
# 17              5.3   83088.0   75877.000502
# 18              5.9   81363.0   81546.977895
# 19              6.0   93940.0   82491.974127
# ...

# %%
model.resid
# Out:
# 0      3155.841248
# 1      8127.848783
# 2     -2236.143681
# 3     -1167.124842
# 4     -6691.117306
# 5      3444.909069
# 6      6007.912837
# 7     -1587.079627
# 8      8412.920373
# 9     -3568.060788
# 10      570.946748
# 11    -7798.049484
# 12    -6635.049484
# 13    -7456.045717
# 14    -7206.030645
# 15    -4159.015574
# 16    -7958.008038
# 17     7210.999498
# 18     -183.977895
# 19    11448.025873
# 20     1686.056015
# 21     5386.067319
# 22      855.097462
# 23    10530.108765
# 24     1424.127605
# 25    -5259.861092
# 26     1402.157748
# 27    -3876.838485
# 28     -735.812110
# 29    -3144.804574
# dtype: float64

# %%
Salary['Error']=model.resid
Salary
# Out:
#     YearsExperience    Salary      Predicted         Error
# 0               1.1   39343.0   36187.158752   3155.841248
# 1               1.3   46205.0   38077.151217   8127.848783
# 2               1.5   37731.0   39967.143681  -2236.143681
# 3               2.0   43525.0   44692.124842  -1167.124842
# 4               2.2   39891.0   46582.117306  -6691.117306
# 5               2.9   56642.0   53197.090931   3444.909069
# 6               3.0   60150.0   54142.087163   6007.912837
# 7               3.2   54445.0   56032.079627  -1587.079627
# 8               3.2   64445.0   56032.079627   8412.920373
# 9               3.7   57189.0   60757.060788  -3568.060788
# 10              3.9   63218.0   62647.053252    570.946748
# 11              4.0   55794.0   63592.049484  -7798.049484
# 12              4.0   56957.0   63592.049484  -6635.049484
# 13              4.1   57081.0   64537.045717  -7456.045717
# 14              4.5   61111.0   68317.030645  -7206.030645
# ...

# %%
Salary['Errors_Sq']=(Salary['Error'])**2
Salary
# Out:
#     YearsExperience    Salary      Predicted         Error     Errors_Sq
# 0               1.1   39343.0   36187.158752   3155.841248  9.959334e+06
# 1               1.3   46205.0   38077.151217   8127.848783  6.606193e+07
# 2               1.5   37731.0   39967.143681  -2236.143681  5.000339e+06
# 3               2.0   43525.0   44692.124842  -1167.124842  1.362180e+06
# 4               2.2   39891.0   46582.117306  -6691.117306  4.477105e+07
# 5               2.9   56642.0   53197.090931   3444.909069  1.186740e+07
# 6               3.0   60150.0   54142.087163   6007.912837  3.609502e+07
# 7               3.2   54445.0   56032.079627  -1587.079627  2.518822e+06
# 8               3.2   64445.0   56032.079627   8412.920373  7.077723e+07
# 9               3.7   57189.0   60757.060788  -3568.060788  1.273106e+07
# 10              3.9   63218.0   62647.053252    570.946748  3.259802e+05
# 11              4.0   55794.0   63592.049484  -7798.049484  6.080958e+07
# ...

# %%
#Intercept          25792.200199
#YearsExperience     9449.962321
Salary['Salary_Hike']= 25792.200199 + (9449.962321 * Salary['YearsExperience']+Salary['Error'])
Salary[0:5]
# Out:
#    YearsExperience   Salary     Predicted        Error     Errors_Sq  \
# 0              1.1  39343.0  36187.158752  3155.841248  9.959334e+06
# 1              1.3  46205.0  38077.151217  8127.848783  6.606193e+07
# 2              1.5  37731.0  39967.143681 -2236.143681  5.000339e+06
# 3              2.0  43525.0  44692.124842 -1167.124842  1.362180e+06
# 4              2.2  39891.0  46582.117306 -6691.117306  4.477105e+07
#
#     Salary_Hike
# 0  39343.000000
# 1  46205.000000
# 2  37731.000000
# 3  43524.999999
# 4  39890.999999

# %%
Mean_Squared_Error=Salary['Errors_Sq'].mean()
Mean_Squared_Error
# Out:
# 31270951.72228097

# %%
model.rsquared
# Out:
# 0.9569566641435086

# %%
model.pvalues
# Out:
# Intercept          5.511950e-12
# YearsExperience    1.143068e-20
# dtype: float64

# %%
Salary['SQRT_YearsExperience']=np.sqrt(Salary['YearsExperience'])
Salary
# Out:
#     YearsExperience    Salary      Predicted         Error     Errors_Sq  \
# 0               1.1   39343.0   36187.158752   3155.841248  9.959334e+06
# 1               1.3   46205.0   38077.151217   8127.848783  6.606193e+07
# 2               1.5   37731.0   39967.143681  -2236.143681  5.000339e+06
# 3               2.0   43525.0   44692.124842  -1167.124842  1.362180e+06
# 4               2.2   39891.0   46582.117306  -6691.117306  4.477105e+07
# 5               2.9   56642.0   53197.090931   3444.909069  1.186740e+07
# 6               3.0   60150.0   54142.087163   6007.912837  3.609502e+07
# 7               3.2   54445.0   56032.079627  -1587.079627  2.518822e+06
# 8               3.2   64445.0   56032.079627   8412.920373  7.077723e+07
# 9               3.7   57189.0   60757.060788  -3568.060788  1.273106e+07
# 10              3.9   63218.0   62647.053252    570.946748  3.259802e+05
# 11              4.0   55794.0   63592.049484  -7798.049484  6.080958e+07
# ...

# %%
import statsmodels.formula.api as smf

# %%
model = smf.ols("Salary~SQRT_YearsExperience",data=Salary).fit()
Salary
# Out:
#     YearsExperience    Salary      Predicted         Error     Errors_Sq  \
# 0               1.1   39343.0   36187.158752   3155.841248  9.959334e+06
# 1               1.3   46205.0   38077.151217   8127.848783  6.606193e+07
# 2               1.5   37731.0   39967.143681  -2236.143681  5.000339e+06
# 3               2.0   43525.0   44692.124842  -1167.124842  1.362180e+06
# 4               2.2   39891.0   46582.117306  -6691.117306  4.477105e+07
# 5               2.9   56642.0   53197.090931   3444.909069  1.186740e+07
# 6               3.0   60150.0   54142.087163   6007.912837  3.609502e+07
# 7               3.2   54445.0   56032.079627  -1587.079627  2.518822e+06
# 8               3.2   64445.0   56032.079627   8412.920373  7.077723e+07
# 9               3.7   57189.0   60757.060788  -3568.060788  1.273106e+07
# 10              3.9   63218.0   62647.053252    570.946748  3.259802e+05
# 11              4.0   55794.0   63592.049484  -7798.049484  6.080958e+07
# ...

# %%
model.params
# Out:
# Intercept              -16055.769117
# SQRT_YearsExperience    41500.680583
# dtype: float64

# %%
model.fittedvalues
# Out:
# 0      27470.511884
# 1      31262.287009
# 2      34771.976586
# 3      42635.056211
# 4      45499.687794
# 5      54617.343293
# 6      55825.518202
# 7      58182.905200
# 8      58182.905200
# 9      63772.383867
# 10     65901.508208
# 11     66945.592049
# 12     66945.592049
# 13     67976.704394
# 14     71980.468875
# 15     75809.903446
# 16     77665.963118
# 17     79485.972499
# 18     84749.033766
# 19     85599.722290
# 20     92164.765553
# 21     94526.218887
# 22    100589.939171
# 23    102784.094601
# 24    106353.652306
# 25    108446.272632
# 26    111857.919142
# 27    112529.386687
# 28    117134.909368
# 29    118421.805716
# dtype: float64

# %%
model.resid
# Out:
# 0     11872.488116
# 1     14942.712991
# 2      2959.023414
# 3       889.943789
# 4     -5608.687794
# 5      2024.656707
# 6      4324.481798
# 7     -3737.905200
# 8      6262.094800
# 9     -6583.383867
# 10    -2683.508208
# 11   -11151.592049
# 12    -9988.592049
# 13   -10895.704394
# 14   -10869.468875
# 15    -7871.903446
# 16   -11636.963118
# 17     3602.027501
# 18    -3386.033766
# 19     8340.277710
# 20     -426.765553
# 21     3746.781113
# 22      712.060829
# 23    11027.905399
# 24     3077.347694
# 25    -2864.272632
# 26     5111.080858
# 27      105.613313
# 28     5256.090632
# 29     3450.194284
# dtype: float64

# %%
Salary['SQRT_Predicted']=model.fittedvalues
Salary['SQRT_Errors']=model.resid
Salary.head()
# Out:
#    YearsExperience   Salary     Predicted        Error     Errors_Sq  \
# 0              1.1  39343.0  36187.158752  3155.841248  9.959334e+06
# 1              1.3  46205.0  38077.151217  8127.848783  6.606193e+07
# 2              1.5  37731.0  39967.143681 -2236.143681  5.000339e+06
# 3              2.0  43525.0  44692.124842 -1167.124842  1.362180e+06
# 4              2.2  39891.0  46582.117306 -6691.117306  4.477105e+07
#
#     Salary_Hike  SQRT_YearsExperience  SQRT_Predicted   SQRT_Errors
# 0  39343.000000              1.048809    27470.511884  11872.488116
# 1  46205.000000              1.140175    31262.287009  14942.712991
# 2  37731.000000              1.224745    34771.976586   2959.023414
# 3  43524.999999              1.414214    42635.056211    889.943789
# 4  39890.999999              1.483240    45499.687794  -5608.687794

# %%
Salary['SQRT_Errors_Sq']=Salary['SQRT_Errors']**2
Salary.head()
# Out:
#    YearsExperience   Salary     Predicted        Error     Errors_Sq  \
# 0              1.1  39343.0  36187.158752  3155.841248  9.959334e+06
# 1              1.3  46205.0  38077.151217  8127.848783  6.606193e+07
# 2              1.5  37731.0  39967.143681 -2236.143681  5.000339e+06
# 3              2.0  43525.0  44692.124842 -1167.124842  1.362180e+06
# 4              2.2  39891.0  46582.117306 -6691.117306  4.477105e+07
#
#     Salary_Hike  SQRT_YearsExperience  SQRT_Predicted   SQRT_Errors  \
# 0  39343.000000              1.048809    27470.511884  11872.488116
# 1  46205.000000              1.140175    31262.287009  14942.712991
# 2  37731.000000              1.224745    34771.976586   2959.023414
# 3  43524.999999              1.414214    42635.056211    889.943789
# 4  39890.999999              1.483240    45499.687794  -5608.687794
#
#    SQRT_Errors_Sq
# 0    1.409560e+08
# 1    2.232847e+08
# 2    8.755820e+06
# 3    7.919999e+05
# 4    3.145738e+07

# %%
Salary['Salary_Hike']= 25792.200199 + (9449.962321 * Salary['YearsExperience']+Salary['Error'])
Salary[0:5]
# Out:
#    YearsExperience   Salary     Predicted        Error     Errors_Sq  \
# 0              1.1  39343.0  36187.158752  3155.841248  9.959334e+06
# 1              1.3  46205.0  38077.151217  8127.848783  6.606193e+07
# 2              1.5  37731.0  39967.143681 -2236.143681  5.000339e+06
# 3              2.0  43525.0  44692.124842 -1167.124842  1.362180e+06
# 4              2.2  39891.0  46582.117306 -6691.117306  4.477105e+07
#
#     Salary_Hike  SQRT_YearsExperience  SQRT_Predicted   SQRT_Errors  \
# 0  39343.000000              1.048809    27470.511884  11872.488116
# 1  46205.000000              1.140175    31262.287009  14942.712991
# 2  37731.000000              1.224745    34771.976586   2959.023414
# 3  43524.999999              1.414214    42635.056211    889.943789
# 4  39890.999999              1.483240    45499.687794  -5608.687794
#
#    SQRT_Errors_Sq
# 0    1.409560e+08
# 1    2.232847e+08
# 2    8.755820e+06
# 3    7.919999e+05
# 4    3.145738e+07

# %%
#Intercept              -16055.769117
#SQRT_YearsExperience    41500.680583
Salary['SQRT_Y']=-16055.769117 + (41500.680583 * Salary['SQRT_YearsExperience']+Salary['SQRT_Errors'])
Salary[0:5]
# Out:
#    YearsExperience   Salary     Predicted        Error     Errors_Sq  \
# 0              1.1  39343.0  36187.158752  3155.841248  9.959334e+06
# 1              1.3  46205.0  38077.151217  8127.848783  6.606193e+07
# 2              1.5  37731.0  39967.143681 -2236.143681  5.000339e+06
# 3              2.0  43525.0  44692.124842 -1167.124842  1.362180e+06
# 4              2.2  39891.0  46582.117306 -6691.117306  4.477105e+07
#
#     Salary_Hike  SQRT_YearsExperience  SQRT_Predicted   SQRT_Errors  \
# 0  39343.000000              1.048809    27470.511884  11872.488116
# 1  46205.000000              1.140175    31262.287009  14942.712991
# 2  37731.000000              1.224745    34771.976586   2959.023414
# 3  43524.999999              1.414214    42635.056211    889.943789
# 4  39890.999999              1.483240    45499.687794  -5608.687794
#
#    SQRT_Errors_Sq   SQRT_Y
# 0    1.409560e+08  39343.0
# 1    2.232847e+08  46205.0
# 2    8.755820e+06  37731.0
# ...

# %%
MSE=Salary['SQRT_Errors_Sq'].mean()
MSE
# Out:
# 50127755.61652503

# %%
model.rsquared
# Out:
# 0.9310009544993526

# %%
model.pvalues
# Out:
# Intercept               2.906965e-03
# SQRT_YearsExperience    8.565358e-18
# dtype: float64

# %% [markdown]
# **DELIVERY DATA**

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-88a2d46b-fa30-476e-89f8-2686aa08b1ba" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-88a2d46b-fa30-476e-89f8-2686aa08b1ba">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
Time=pd.read_csv("delivery_time.csv")
Time
# Out:
#     Delivery Time  Sorting Time
# 0           21.00            10
# 1           13.50             4
# 2           19.75             6
# 3           24.00             9
# 4           29.00            10
# 5           15.35             6
# 6           19.00             7
# 7            9.50             3
# 8           17.90            10
# 9           18.75             9
# 10          19.83             8
# 11          10.75             4
# 12          16.68             7
# 13          11.50             3
# 14          12.03             3
# 15          14.88             4
# 16          13.75             6
# 17          18.11             7
# 18           8.00             2
# 19          17.83             7
# 20          21.50             5

# %%
Time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Delivery Time  21 non-null     float64
#  1   Sorting Time   21 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 464.0 bytes

# %%
Time.isnull().sum()
# Out:
# Delivery Time    0
# Sorting Time     0
# dtype: int64

# %%
Time.rename(columns={'Delivery Time':'DeliveryTime','Sorting Time':'SortingTime'},inplace=True)

# %%
import seaborn as sns
sns.scatterplot(x='DeliveryTime',y='SortingTime',data=Time)
# Out:
# <Axes: xlabel='DeliveryTime', ylabel='SortingTime'>

# %%
Time.corr()
# Out:
#               DeliveryTime  SortingTime
# DeliveryTime      1.000000     0.825997
# SortingTime       0.825997     1.000000

# %%
sns.distplot(Time['DeliveryTime'])
# Out:
# <ipython-input-46-63dcc5d263b9>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(Time['DeliveryTime'])
# <Axes: xlabel='DeliveryTime', ylabel='Density'>

# %%
sns.distplot(Time['SortingTime'])
# Out:
# <ipython-input-47-5434b660061e>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(Time['SortingTime'])
# <Axes: xlabel='SortingTime', ylabel='Density'>

# %%
import statsmodels.formula.api as smf

# %%
model=smf.ols('SortingTime~DeliveryTime',data=Time).fit()

# %%
sns.regplot(x='DeliveryTime',y='SortingTime',data=Time)
# Out:
# <Axes: xlabel='DeliveryTime', ylabel='SortingTime'>

# %%
model.params
# Out:
# Intercept      -0.756673
# DeliveryTime    0.413744
# dtype: float64

# %%
model.fittedvalues
# Out:
# 0      7.931943
# 1      4.828866
# 2      7.414763
# 3      9.173174
# 4     11.241892
# 5      5.594291
# 6      7.104456
# 7      3.173891
# 8      6.649338
# 9      7.001020
# 10     7.447863
# 11     3.691071
# 12     6.144570
# 13     4.001378
# 14     4.220662
# 15     5.399832
# 16     4.932302
# 17     6.736224
# 18     2.553276
# 19     6.620376
# 20     8.138815
# dtype: float64

# %%
Time
# Out:
#     DeliveryTime  SortingTime
# 0          21.00           10
# 1          13.50            4
# 2          19.75            6
# 3          24.00            9
# 4          29.00           10
# 5          15.35            6
# 6          19.00            7
# 7           9.50            3
# 8          17.90           10
# 9          18.75            9
# 10         19.83            8
# 11         10.75            4
# 12         16.68            7
# 13         11.50            3
# 14         12.03            3
# 15         14.88            4
# 16         13.75            6
# 17         18.11            7
# 18          8.00            2
# 19         17.83            7
# 20         21.50            5

# %%
Time['Predicted']=model.fittedvalues
Time
# Out:
#     DeliveryTime  SortingTime  Predicted
# 0          21.00           10   7.931943
# 1          13.50            4   4.828866
# 2          19.75            6   7.414763
# 3          24.00            9   9.173174
# 4          29.00           10  11.241892
# 5          15.35            6   5.594291
# 6          19.00            7   7.104456
# 7           9.50            3   3.173891
# 8          17.90           10   6.649338
# 9          18.75            9   7.001020
# 10         19.83            8   7.447863
# 11         10.75            4   3.691071
# 12         16.68            7   6.144570
# 13         11.50            3   4.001378
# 14         12.03            3   4.220662
# 15         14.88            4   5.399832
# 16         13.75            6   4.932302
# 17         18.11            7   6.736224
# 18          8.00            2   2.553276
# 19         17.83            7   6.620376
# 20         21.50            5   8.138815

# %%
model.resid
# Out:
# 0     2.068057
# 1    -0.828866
# 2    -1.414763
# 3    -0.173174
# 4    -1.241892
# 5     0.405709
# 6    -0.104456
# 7    -0.173891
# 8     3.350662
# 9     1.998980
# 10    0.552137
# 11    0.308929
# 12    0.855430
# 13   -1.001378
# 14   -1.220662
# 15   -1.399832
# 16    1.067698
# 17    0.263776
# 18   -0.553276
# 19    0.379624
# 20   -3.138815
# dtype: float64

# %%
Time['Errors']=model.resid
Time
# Out:
#     DeliveryTime  SortingTime  Predicted    Errors
# 0          21.00           10   7.931943  2.068057
# 1          13.50            4   4.828866 -0.828866
# 2          19.75            6   7.414763 -1.414763
# 3          24.00            9   9.173174 -0.173174
# 4          29.00           10  11.241892 -1.241892
# 5          15.35            6   5.594291  0.405709
# 6          19.00            7   7.104456 -0.104456
# 7           9.50            3   3.173891 -0.173891
# 8          17.90           10   6.649338  3.350662
# 9          18.75            9   7.001020  1.998980
# 10         19.83            8   7.447863  0.552137
# 11         10.75            4   3.691071  0.308929
# 12         16.68            7   6.144570  0.855430
# 13         11.50            3   4.001378 -1.001378
# 14         12.03            3   4.220662 -1.220662
# 15         14.88            4   5.399832 -1.399832
# 16         13.75            6   4.932302  1.067698
# ...

# %%
Time['Errors_Sq']=Time['Errors']**2
Time
# Out:
#     DeliveryTime  SortingTime  Predicted    Errors  Errors_Sq
# 0          21.00           10   7.931943  2.068057   4.276860
# 1          13.50            4   4.828866 -0.828866   0.687018
# 2          19.75            6   7.414763 -1.414763   2.001555
# 3          24.00            9   9.173174 -0.173174   0.029989
# 4          29.00           10  11.241892 -1.241892   1.542295
# 5          15.35            6   5.594291  0.405709   0.164600
# 6          19.00            7   7.104456 -0.104456   0.010911
# 7           9.50            3   3.173891 -0.173891   0.030238
# 8          17.90           10   6.649338  3.350662  11.226939
# 9          18.75            9   7.001020  1.998980   3.995922
# 10         19.83            8   7.447863  0.552137   0.304856
# 11         10.75            4   3.691071  0.308929   0.095437
# 12         16.68            7   6.144570  0.855430   0.731760
# 13         11.50            3   4.001378 -1.001378   1.002759
# ...

# %%
#Intercept      -0.756673
#DeliveryTime    0.413744
Time['Y']=-0.756673+(0.413744*Time['DeliveryTime']+Time['Errors'])
Time
# Out:
#     DeliveryTime  SortingTime  Predicted    Errors  Errors_Sq          Y
# 0          21.00           10   7.931943  2.068057   4.276860  10.000008
# 1          13.50            4   4.828866 -0.828866   0.687018   4.000005
# 2          19.75            6   7.414763 -1.414763   2.001555   6.000008
# 3          24.00            9   9.173174 -0.173174   0.029989   9.000009
# 4          29.00           10  11.241892 -1.241892   1.542295  10.000011
# 5          15.35            6   5.594291  0.405709   0.164600   6.000006
# 6          19.00            7   7.104456 -0.104456   0.010911   7.000007
# 7           9.50            3   3.173891 -0.173891   0.030238   3.000004
# 8          17.90           10   6.649338  3.350662  11.226939  10.000007
# 9          18.75            9   7.001020  1.998980   3.995922   9.000007
# 10         19.83            8   7.447863  0.552137   0.304856   8.000008
# 11         10.75            4   3.691071  0.308929   0.095437   4.000004
# ...

# %%
Mean_Squared_Error=Time['Errors_Sq'].mean()
Mean_Squared_Error
# Out:
# 1.9553633044888064

# %%
model.rsquared
#68%
# Out:
# 0.682271474841723

# %%
model.pvalues
# Out:
# Intercept       0.512611
# DeliveryTime    0.000004
# dtype: float64
